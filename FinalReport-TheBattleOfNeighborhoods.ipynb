# %% [markdown]
# # <center>Recommending Best Neighborhood In Toronto For Opening A Restaurant </center>

# %% [markdown]
# ### <center>Applied Data Science Capstone Project : The Battle Of Neighborhoods </center>

# %% [markdown]
# <center>Author :  Avinandan Mukherjee </center>

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ![](https://wallpapercave.com/wp/wp6894293.jpg)

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ## <u>Introduction</u>

# %% [markdown]
# ### Background

# %% [markdown]
# __ABC company__ hired a bunch of Data Science professionals to build a recommendation system to their new proposed venture.
# The aim of this project is to explore the city of Toronto data and build a recommender system to start a new restaurant for ABC Company using the existing data collected over a period of time describing verious relateed features. To open a new restaurant it is important to it is impotant to understand the demographic of Toronto with the market study to analyze the competition and sustainability.

# %% [markdown]
# ### Overview

# %% [markdown]
# __Toronto__, the capital of the province of Ontario, is a most populous Canadian city along Lake Ontario’s northwestern shore.
# It has a population of 2.8 million and it is at the heart of the Greater Toronto Area (GTA) which contains a further 6.2 million people in total. The city is the anchor of the __Golden Horseshoe region__ in Southern Ontario which wraps around __Lake Ontario__ from Toronto to __Niagara Falls__ and totals over 8.5 million residents, approximately a quarter of Canada's entire population. Toronto is the fourth largest city and fifth largest urban agglomeration in North America.
#
# Toronto encompasses a geographical area formerly administered by many separate municipalities. Each have developed a distinct history and identity over the years and their names remain in common use among Torontonians. Former municipalities include __East York, Etobicoke, Forest Hill, Mimico, North York, Parkdale, Scarborough, Swansea, Weston__ and __York__. Throughout the city there exist hundreds of small neighbourhoods and some larger neighbourhoods covering a few square kilometres.
#
# Due to such vast diverse population and big geographical area, there also exists big competition between businesses. Therefore it became very challenging for stake holders or new business to decide which area they should start their business to get higher revenue with lowest possible competition and better revenue with sutainability. As it is a one of the major developed city so cost of doing business is also one of the highest. Thus, any new business venture or expansion needs to be analysed carefully. The insights derived from analysis will give good understanding of the business environment which help in strategically targeting the market. This will help in reduction of risk and better ROI.

# %% [markdown]
# __Toronto__ is generally considered to be one of North America's top food cities. As one of the most (if not the single most) multicultural cities in the world, Toronto has authentic cuisine from most of the world's cultural and ethnic groups. It is easy to eat out in Toronto and have a superb meal for cheap, while even the more distant neighbourhoods in the city frequently contain one or more ethnic grocers' with both local stock and freshly imported products and brands from all over the world. Since Toronto is a city of a wide variety of distinct neighbourhoods, there are excellent restaurants scattered across the city. Many of the trendiest and hottest restaurants in Toronto are located outside of the downtown core and visitors should be prepared to travel a short drive or transit trip to visit them.
#
# A restaurant is a business which prepares and serves food and drink to customers in return for money, either paid before the meal, after the meal, with an open account or paid virtually serving pick-ups and lastly deliveries considering the ongoing pandemic. The metropolitian has some existing interesting food districs namely:
# * Cabbagetown
# * Baldwin Village
# * Chinatown
# * Hakka Food
# * King Street (between University Ave & Spadina Ave)
# * Queen Street (between Empire & Leslie), College Street
# * Bayview Ave, Bloor St
# * Yorkville
# * Downsview Park Flea Market food court

# %% [markdown]
# ### Business Problem

# %% [markdown]
# With _Canada_ being immigrant friendly country with expected to _welcome around 1.2 Million immigrants by 2023_ __ABC Company__ decided to extend its venture in Tornoto and establish a strong foothold in the restaurant business. Since they are planning to open a new restaurant in the best possible neighborhood in Tornoto, it's important to evaluate the risk for a better return of investment.
# So it is evident that to survive in such competitive market it is very important to startegically plan.
# <br>Various factors need to be studied inorder to decide on the Location such as:
# * Toronto Neighborhood Population
# * Toronto Demographics using postal codes
# * Toronto Neighborhoods Average net income
# * Crime in the neighborhoods
# * List of existig competitors(Restaurants) in that location by postal codes
# We  KPI that can be consider

# %% [markdown]
# #### Requirements

# %% [markdown]
# 1. Restaurants needs to located in nicely populated area with a neighborhood.
# 2. Restaurants needs to located in a neighborhood where the criminal activites are lower or negligible.
# 3. Restaurants needs to located strategically with the existing competetion in the market for a sustainable growth.
# 4. Restaurants needs to located in a neighborhood with above average net income of the nation.

# %% [markdown]
# ### Target Audience

# %% [markdown]
# I have been assigned as the Lead Data Scientist to accomplish this task to recommend a fruitful location to open a new reataurant in the neighborhoods of Tonoto by ABC Company. The leadership also expects to understand the logical reasoning behind the analysis of this recommendation engine.

# %% [markdown]
# #### Success Criteria

# %% [markdown]
# The reccomendation system will consider to be a success where ABC Company can open a retaurant which can operate smoothly with a steady revenue in that neighborhood with close proxiity to neareast suppliers. So following KPIs can be ensured:
# * Location of the restaurant with the neighborhood
# * Measure existing competetion by clustering common restaurants by neighborhoods
# * Mean income of the neighborhood with Canadian National Average
# * Population by neighborhood
# * Crime in the neigborhoods

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## <u>Data</u>

# %% [markdown]
# ### Data Description

# %% [markdown]
# In this project, we will explore & analyse the data of __Toronto__ that were obtained from few sources whose links are proided below.
# <br>These sources are __Wikipedia, City Of Toronto Open Data Portal, Kaggle, StatsCan__ portal primarily. These data were then pre-processed before used in model building.
# <br> These data were either downloded directly in the jupyter notebook or were loded from local machine after initial Data Cleaning or sometimes were loaded from the IBM Watson Data Studio assets as needed. After which Data Wrnagling was perfomed to the best suit and then model was built.

# %% [markdown]
# #### Data Loading, Data Cleaning & Data Wrangling

# %% [markdown]
# __1. Toronto Neighborhoods & Demography Data__
# <br>
# <br>
# _1.1 List of Toronto Neighborhoods by Postal Code_
# <br>
# I have usied the Wikipedia dataset as my base for the list of neighborhoods from the following link:
# <br>
# <https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M>
# <br> Here I have used BeautifulSoup to scrape the wiki page to extract a working list of Toronto Neighborhoods sorted by postal code.

# %% [markdown]
# ![Screenshot%202021-01-13%20183620.jpg](attachment:Screenshot%202021-01-13%20183620.jpg)

# %% [markdown]
# _1.2. List of Toroto neighborhood population broken down by Postal Code_
# <br>
# I have imported the list of polulations by Postal Code from the following link:
# <br>
# <https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Tables/File.cfm?T=1201&SR=1&RPP=9999&PR=0&CMA=0&CSD=0&S=22&O=A&Lang=Eng&OFT=CSV>
# <br>Refer file: to_geo_space.csv
# <br> Using __Pandas__ to grab the csv from the link.

# %% [markdown]
# _1.3. Load of Toroto Geo Coordinates data & merge with Postal Code_
# <br>
# I have imported the list of polulations by Postal Code from the following link:
# <br>
# http://cocl.us/Geospatial_data
# <br>Refer file: to_geo_space.csv
# <br> Using __Pandas__ to grab the csv from the link.

# %% [markdown]
# ![Screenshot%202021-01-13%20184126.jpg](attachment:Screenshot%202021-01-13%20184126.jpg)

# %% [markdown]
# __2. Toronto Neighborhoods Income & Crimes Data__
# <br>
# <br>
# _2.1. Canandian National Average on Net Income_
# <br>
# Download this data from the following website link:
# <br>
# <https://www150.statcan.gc.ca/n1/daily-quotidien/180313/dq180313a-eng.htm>
# <br>In 2016, Canadian families & unattched individuals had a median post-tax income of $57,000.
# <br>
# Refer: MeanIncomeCA.csv
# <br>
# <br>
# _2.2.Toronto Neighborhoods Crimes from Tronto Police Data_
# <br>
# Download this data manually from the following website link below. Perform Data Cleaning in Excel and filter out crimes onky for Commercial premises.
# <br>
# <https://www.kaggle.com/kapastor/toronto-police-data-crime-rates-by-neighbourhood>
# <br>
# Refer file: TorontoCrime.csv

# %% [markdown]
# ![Screenshot%202021-01-13%20185551.jpg](attachment:Screenshot%202021-01-13%20185551.jpg)

# %% [markdown]
# __Observation:__ Of the 103 Toronto Neighborhoods gathered only 55.3% or 57 Neighborhoods are above the median after-tax income. 37.8% or 39 Neighborhoods are below he median after-tax income. 6.7% or 7 neighborhoods did not register as it appears their populations are too low. It appears that the greatest concentration of affluence is near central Toronto. We decided to keep all neighborhoods in the dataset regardless of income of population as the majority were close enough.
# <br>

# %% [markdown]
# ### Segmenting & Clustering

# %% [markdown]
# __1. Toronto list of Restaurants with Venues by Postal Code__
# <br>
# <br>
# _1.1_ Toronto geographical coordinates data will be utilized as input for the __Foursquare API__, that will be leveraged to provision venues information for each neighborhood. We will use the Foursquare API to explore neighborhoods in Toronto.
# <br>
# <https://api.foursquare.com>
# <br>
# <br>
# _1.2_ Get All the list of 'Venues' in Toronto.
# <br>
# <br>
# _1.3_ Add __Restaurants__ as 'Venue Category'.
# <br> Extract only restaurants from this to include in our dataset.
# <br>

# %% [markdown]
# ![Screenshot%202021-01-13%20191732.jpg](attachment:Screenshot%202021-01-13%20191732.jpg)

# %% [markdown]
# __2. One-Hot Encoding and counting restaurants__
# <br>
# <br>
# Prepared the data for __clustering__.
# Combine all of those into a working Data Set to cluster and geo spatial map of the results showing the best neighborhood to open a Restaurant.
# Combining all of these disparate data sets will clearly demonstrate the following:
# * how populated each neighborhoods is
# * which neighborhoods in Toronto have clusters of like existing Restaurants
# * crime incidents of these neighborhoods
# * which neighborhood should be target to open the new store for ABC Company
# <br>

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## <u>Methodology</u>

# %% [markdown]
# Here, I will discuss about the approach taken and the Python libraries used while working on this project. The libraries and packeges used in the Jupyter Notebook are as below:
# <br>
# * Pandas - For storing & manipulating structured data.
# * Numpy - For multi-dimensional array and matrix data structure.
# * Scikie Learn - For performing Machine Learning tasks.
# * Folium - For plotting the map & visualization
# * Requests - For sending HTTP requests easliy
# * BeautifulSoup - For Web Scraping
# * KMeans - For Clustering
# * Silhouette - For determining the optimum number of clusters

# %% [markdown]
# ![Screenshot%202021-01-13%20195524.jpg](attachment:Screenshot%202021-01-13%20195524.jpg)
# <br>
# <center><u> Project Flowchart </u></center>

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Initial Data Collection and Visualization of Toronto Neighborhoods

# %% [markdown]
# The loaded neighborhoods geospatial coordindates data were conbverted into a Pandas dataframe and then imposed on Steet map of Tornoto using __Folium__ library after performing the data cleaning and data wrangling. Folium makes it easy to visualize data that’s been manipulated in Python on an interactive leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing rich vector/raster/HTML visualizations as markers on the map. It supports both Image, Video, GeoJSON and TopoJSON overlays.
# <br>
# ![Screenshot%202021-01-14%20180615.jpg](attachment:Screenshot%202021-01-14%20180615.jpg)

# %% [markdown]
# #### Determining top Toronto venues by Neighbourhood to check the competetion - Segmenting & Clustering

# %% [markdown]
# Here the primary aim was to measure the narrow down type venues and analyze existing comeptetion. From the Foursqare API call, I found that there area 46 unique categories in Tornoto neighborhood.
# <br>![Screenshot%202021-01-20%20180730.jpg](attachment:Screenshot%202021-01-20%20180730.jpg)
# After sorting the list of venues retrieved through the Foursquare API by venue category, I performed One-Hot encoding to convert venue categories to numerical formats for each neighborhood. Then a new dataframe was created showing all the neighborhoods and total number of each venue type.
# <br>![Screenshot%202021-01-20%20181253.jpg](attachment:Screenshot%202021-01-20%20181253.jpg)

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### Algorithm Choice

# %% [markdown]
# To perform clustering I have choosed __K-Means__ clustering algorithm.
# <br>“K-Means clustering is an iterative clustering algorithm where the number of clusters K is predetermined and the algorithm iteratively assigns each data
# point to one of the K clusters based on the feature similarity.”
# <br> [Reference Link](https://towardsdatascience.com/k-means-clustering-one-rule-to-group-them-all-f47e00720ee7)

# %% [markdown]
# #### Choosing the correct number of clusters

# %% [markdown]
# Here I use __Silhouette analysis__ to determine the optimum number of clusters to use.
# <br>We can use Silhouette analysis to evaluate each model. A Silhouette coefficient is calculated for observation, which is then averaged to determine the Silhouette score. The coefficient combines the average within-cluster distance with average nearest-cluster distance to assign a value between -1 and 1.
# <br>A value below zero denotes that the observation is probably in the wrong cluster and a value closer to 1 denotes that the observation is a great fit for the cluster and clearly separated from other clusters. This coefficient essentially measures how close an observation is to neighboring clusters, where it is desirable to be the maximum distance possible from neighboring clusters. We can automatically determine the best number of clusters, k, by selecting the model which yields the highest Silhouette score.
# <br>[Referrence Link](https://www.jeremyjordan.me/grouping-data-points-with-k-means-clustering/)
# <br> __My Silhouette score was 2__
# <br>
# <br>![Screenshot%202021-01-20%20184434.jpg](attachment:Screenshot%202021-01-20%20184434.jpg)

# %% [markdown]
# ### Clustering Neighborhoods

# %% [markdown]
# __Run K means and segment data into clusters and generate labels__
# <br>
# <br>__Merging Toronto data with geo spatial data__
# <br>Reshaped the Troronto data to match the clustered data.
# <br>
# <br>__Add the KMeans Labels__
# <br>Determine the largest cluster here is cluster number 2 with the shape
# <br>(83, 6)
# <br>![Screenshot%202021-01-15%20000925.jpg](attachment:Screenshot%202021-01-15%20000925.jpg)
# <br>
# <br>__Find the centroid of the highest cluster density.__
# <br>Now that I know that Cluster 2 is the best cluster from the Silhoutte Score & K-means clustering. Here taking the average latitude and longitude to be the centroid, I will reverse lookup the coordinates for the best neighorhood.
# <br>
# <br>__Lastly visualize the result.__
# <br> Using __Geocoder__ & __Folium__. These are shown in the next section.

# %% [markdown]
# ## <u> Result</u>

# %% [markdown]
# Our analysis shows that although there is a great number of restaurants in Toronto, the best location to open a new restaurant for ABC company is in Central Toronto. We have 4 boroughs and 74 neighborhoods inside geograpical coordinate of __43.6534817, -79.3839347.__
# <br>![Screenshot%202021-01-15%20000521.jpg](attachment:Screenshot%202021-01-15%20000521.jpg)
# <br>
# <br> Using the previous step (Methodology), we are able to obtain two distint maps of Tornoto:
# <br>* Tonroto Neighborhoods venues map.
# <br>* Best possible neighborhood to superimposed on the Tornoto Map after clustering to open a new restaurant meeting our KPI.
# <br>![Screenshot%202021-01-14%20180918.jpg](attachment:Screenshot%202021-01-14%20180918.jpg)
# <br><center> __Best Neighborhood Map__ </center>

# %% [markdown]
# ## <u>Discussion</u>

# %% [markdown]
# As I built our list of neighborhoods with Restaurant venues exclusively I discovered most neighborhoods were similar and the greatest concentration of restaurants was in Central Toronto and downtown Toronto. This might seem obvious but it would also appear that these are some of the most affluent neighborhoods in Toronto so there appears to be correlation. By Locating in the general vicinity of this location ABC company could be geographically centered in this cluster and poised to service his restaurant customer base with greatest efficiency even during the pandemic times.
# <br>
# <br>When I built our our K-Means dataset, I used Silhouette analysis to tell us there was a lot of similarity between neighborhoods and the most common restaurants contained with in to analyse the existing competetion. Really there was only 2 types of cluster or neighborhoods in greater Toronto. The vast majority of those were in 1 cluster. So Toronto restaurants might be many but they are very homogeneously located near the center of Toronto.
# <br>
# <br>Even with such a large population, Toronto’s regarded as a very safe city. Here are Toronto’s safest neighbourhoods:
# * Forest Hill South
# * Bridle Path – Sunnybrook – York Mills
# * Lawrence Park
# * Yonge and St. Clair
# * Mount Pleasant East
# <br>It appears that the greatest concentration of affluence is near central Toronto. We decided to keep all neighborhoods in the dataset regardless of income of population as the majority were close enough.
# <br>
# <br>
#
# Some of the drawbacks of this analysis are: the clustering is completely based only on data obtained from Foursquare API and the data about the Indian population distribution in each neighborhood is also based on the 2016 census which is not up-to date. Thus there is huge gap of 4+ years in the population distribution data. Also the crime dataset used in this analysis is aroud the same timeframe leading to miss the recent updates. Even Though there are lots of areas where it can be improved yet this analysis has certainly provided us with some good insights, preliminary information on possibilities & a head start into this business problem by setting the step stones properly.

# %% [markdown]
# ## <u>Conclusion</u>

# %% [markdown]
# The primary purpose of this project was to provide __ABC Company__ with the best possible neighborhood for their new Restaurant venture in Toronto, Canada. This project helps ABC Company get a better understanding of the neighborhoods with respect to the most common venues in that neighborhood with respect to Average Net Canandian National Income and Crime Rate in the neighborhoods. It is always helpful to make use of technology to stay one step ahead i.e. finding out more about places before moving into a neighborhood. I am confident as this result from the Data Science team will help establishing the new venture of ABC Company.
# <br>
# <br>Even though, I built the optimal recommendation system for ABC company in this project but we have to keep in mind that datasets used for this analysis are not latest and so with the most upto date data, our model might vary. We have just taken Population, Average Net Income, Crime and Existing competetion as our KPI to shortlist the borough of Tornoto as per the hypothetical gudelines of ABC Company where as there can by many other impactful factors which can yeild us much better recommendation. As ABC Company wanted we have recommended the most optimum neighborhood based on this analysis to open a new Restaurant in the neighborhood of Tornoto.
# <br>
# <br>That being said, the future of this project includes taking other factors such as specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), proximity to farmers market, connectivity to major neighborhoods as during this pandemic there can be many pick-ups, parking availability, cost of establishment, levels of noise/proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
# <br>Laslty, the final decision for the best restaurant location will be made by potential stakeholders and board of directors. Projects like this can definitely provide them better insights supporting the decision making process.

# %% [markdown]
# <br>
# <br><center> __________________ </center>
